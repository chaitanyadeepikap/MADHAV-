# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanyadeepikap/MADHAV-/blob/main/MADHAV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow nltk

# %%
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
import numpy as np

# Sample text data about weather
text_data = """the weather is sunny
the weather is rainy
it is a cloudy day
the sun is shining
it might rain today
the forecast is clear
the temperature is rising
it is a beautiful day"""
tokens = text_data.lower().splitlines()

# Tokenize text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(tokens)
vocab_size = len(tokenizer.word_index) + 1

# Generate input sequences
input_sequences = []
for line in tokens:
    sequence = tokenizer.texts_to_sequences([line])[0]  # Tokenize each line directly
    for i in range(1, len(sequence)):
        n_gram_sequence = sequence[:i+1]
        input_sequences.append(n_gram_sequence)

# Pad sequences and prepare input-output pairs
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = tf.keras.preprocessing.sequence.pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')
X, y = input_sequences[:,:-1], input_sequences[:,-1]
y = tf.keras.utils.to_categorical(y, num_classes=vocab_size)

# Define simple model
model = Sequential([
    Embedding(vocab_size, 10, input_length=max_sequence_len-1),
    SimpleRNN(50),
    Dense(vocab_size, activation='softmax')
])

# Compile and train model (reduced epochs for speed)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=100, verbose=1)  # Increased epochs for better training

# Function to predict next word
def predict_next_word(model, tokenizer, seed_text, max_sequence_len):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = tf.keras.preprocessing.sequence.pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = model.predict(token_list, verbose=0)
    predicted_word_index = np.argmax(predicted, axis=1)[0]
    for word, index in tokenizer.word_index.items():
        if index == predicted_word_index:
            return word
    return ""

# Test prediction
seed_text = "the weather is"
print(f"Seed text: '{seed_text}'")
print("Predicted next word:", predict_next_word(model, tokenizer, seed_text, max_sequence_len))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.0385 - loss: 3.0092
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.0000e+00 - loss: 2.9966
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.0385 - loss: 2.9844
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2308 - loss: 2.9723
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2692 - loss: 2.9602
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3462 - loss: 2.9480
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3462 - loss: 2.9354
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3462 - loss: 2.9225
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3462 - loss: 2.9089
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3462 - loss: 2.8945
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3077 - loss: 2.8793
# Epoch 12/100
# ...
